# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load in the data and take a look
data = pd.read_csv('C:/Users/kenre/MSBA_Capstone_Python/transactions-cleaned-py.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64555 entries, 0 to 64554
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   trans_id        64555 non-null  int64
#  1   created_date    64555 non-null  object
#  2   expires_date    64555 non-null  object
#  3   user_id         64424 non-null  float64
#  4   product_name    64555 non-null  object
#  5   payment_method  64555 non-null  object
#  6   sub_id          64555 non-null  int64
#  7   amount          64555 non-null  float64
#  8   status          64555 non-null  object
#  9   coupon_id       64555 non-null  int64
#  10  user_ctry       64555 non-null  object
#  11  user_logins     64555 non-null  int64
#  12  on_discord      64555 non-null  int64
#  13  hear_about      64555 non-null  object
#  14  tenure          64555 non-null  int64
#  15  ltv_amount      64555 non-null  float64
# dtypes: float64(3), int64(6), object(7)
# memory usage: 7.9+ MB

# %%
# look at the head
data.head()
# Out:
#    trans_id created_date expires_date  user_id  product_name  \
# 0         3     5/8/2020     6/8/2020      4.0  ROIC Monthly
# 1         7     5/9/2020     6/9/2020      6.0  ROIC Monthly
# 2         9     5/9/2020     6/9/2020      7.0  ROIC Monthly
# 3        12     5/9/2020     6/9/2020      9.0  ROIC Monthly
# 4        15     5/9/2020     6/9/2020     11.0  ROIC Monthly
#
#                payment_method  sub_id  amount    status  coupon_id user_ctry  \
# 0  Debit/Credit Card (Stripe)       2    6.99  complete          0        US
# 1  Debit/Credit Card (Stripe)       5    7.49  complete          0        US
# 2  Debit/Credit Card (Stripe)       6    7.49  complete          0        US
# 3  Debit/Credit Card (Stripe)       8    7.49  complete          0        GB
# 4  Debit/Credit Card (Stripe)      10    7.49   pending       2356        US
#
#    user_logins  on_discord hear_about  tenure  ltv_amount
# 0           50           0    Unknown       8       59.42
# 1           49           0    Unknown      27      202.23
# 2           14           0    Unknown       1        7.49
# 3            3           0    Unknown       8       59.92
# 4            1           0    Unknown       1        0.00

# %%
# change created_date to datetime format
data['created_date'] = pd.to_datetime(data['created_date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64555 entries, 0 to 64554
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   trans_id        64555 non-null  int64
#  1   created_date    64555 non-null  datetime64[ns]
#  2   expires_date    64555 non-null  object
#  3   user_id         64424 non-null  float64
#  4   product_name    64555 non-null  object
#  5   payment_method  64555 non-null  object
#  6   sub_id          64555 non-null  int64
#  7   amount          64555 non-null  float64
#  8   status          64555 non-null  object
#  9   coupon_id       64555 non-null  int64
#  10  user_ctry       64555 non-null  object
#  11  user_logins     64555 non-null  int64
#  12  on_discord      64555 non-null  int64
#  13  hear_about      64555 non-null  object
#  14  tenure          64555 non-null  int64
#  15  ltv_amount      64555 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(6)
# memory usage: 7.9+ MB

# %%
data.head()
# Out:
#    trans_id created_date expires_date  user_id  product_name  \
# 0         3   2020-05-08     6/8/2020      4.0  ROIC Monthly
# 1         7   2020-05-09     6/9/2020      6.0  ROIC Monthly
# 2         9   2020-05-09     6/9/2020      7.0  ROIC Monthly
# 3        12   2020-05-09     6/9/2020      9.0  ROIC Monthly
# 4        15   2020-05-09     6/9/2020     11.0  ROIC Monthly
#
#                payment_method  sub_id  amount    status  coupon_id user_ctry  \
# 0  Debit/Credit Card (Stripe)       2    6.99  complete          0        US
# 1  Debit/Credit Card (Stripe)       5    7.49  complete          0        US
# 2  Debit/Credit Card (Stripe)       6    7.49  complete          0        US
# 3  Debit/Credit Card (Stripe)       8    7.49  complete          0        GB
# 4  Debit/Credit Card (Stripe)      10    7.49   pending       2356        US
#
#    user_logins  on_discord hear_about  tenure  ltv_amount
# 0           50           0    Unknown       8       59.42
# 1           49           0    Unknown      27      202.23
# 2           14           0    Unknown       1        7.49
# 3            3           0    Unknown       8       59.92
# 4            1           0    Unknown       1        0.00

# %%
# drop transaction expiration date from dataframe
data.drop('expires_date', axis=1)
# Out:
#        trans_id created_date  user_id  product_name  \
# 0             3   2020-05-08      4.0  ROIC Monthly
# 1             7   2020-05-09      6.0  ROIC Monthly
# 2             9   2020-05-09      7.0  ROIC Monthly
# 3            12   2020-05-09      9.0  ROIC Monthly
# 4            15   2020-05-09     11.0  ROIC Monthly
# ...         ...          ...      ...           ...
# 64550     73466   2022-07-25   4187.0  ROIC Monthly
# 64551     73467   2022-07-26   6432.0  ROIC Monthly
# 64552     73468   2022-07-26   2521.0  ROIC Monthly
# 64553     73469   2022-07-26   5506.0  ROIC Monthly
# 64554     73470   2022-07-26   6433.0  ROIC Monthly
#
#                    payment_method  sub_id  amount    status  coupon_id  \
# 0      Debit/Credit Card (Stripe)       2    6.99  complete          0
# 1      Debit/Credit Card (Stripe)       5    7.49  complete          0
# 2      Debit/Credit Card (Stripe)       6    7.49  complete          0
# 3      Debit/Credit Card (Stripe)       8    7.49  complete          0
# 4      Debit/Credit Card (Stripe)      10    7.49   pending       2356
# ...                           ...     ...     ...       ...        ...
# 64550  Debit/Credit Card (Stripe)    4789    9.99  complete          0
# 64551  Debit/Credit Card (Stripe)    7596   11.99  complete          0
# 64552  Debit/Credit Card (Stripe)    2828    9.99  complete          0
# 64553  Debit/Credit Card (Stripe)    6356   10.99  complete       6602
# 64554  Debit/Credit Card (Stripe)    7597   11.99  complete          0
#
#       user_ctry  user_logins  on_discord hear_about  tenure  ltv_amount
# 0            US           50           0    Unknown       8       59.42
# 1            US           49           0    Unknown      27      202.23
# 2            US           14           0    Unknown       1        7.49
# 3            GB            3           0    Unknown       8       59.92
# 4            US            1           0    Unknown       1        0.00
# ...         ...          ...         ...        ...     ...         ...
# 64550        US          482           1    YouTube      18      179.82
# 64551        CA          135           1    YouTube      12      143.88
# 64552        US          179           1    Unknown      20      199.80
# 64553        US           39           1    YouTube      15      164.85
# 64554        CA           40           1    YouTube      12      143.88
#
# [64555 rows x 15 columns]

# %%
# drop rows with no user_id
data = data.dropna(subset=['user_id'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64424 entries, 0 to 64554
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   trans_id        64424 non-null  int64
#  1   created_date    64424 non-null  datetime64[ns]
#  2   expires_date    64424 non-null  object
#  3   user_id         64424 non-null  float64
#  4   product_name    64424 non-null  object
#  5   payment_method  64424 non-null  object
#  6   sub_id          64424 non-null  int64
#  7   amount          64424 non-null  float64
#  8   status          64424 non-null  object
#  9   coupon_id       64424 non-null  int64
#  10  user_ctry       64424 non-null  object
#  11  user_logins     64424 non-null  int64
#  12  on_discord      64424 non-null  int64
#  13  hear_about      64424 non-null  object
#  14  tenure          64424 non-null  int64
#  15  ltv_amount      64424 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(6)
# memory usage: 8.4+ MB

# %%
# Find unique products to isolate the monthly subscriptions
products = data.product_name.unique()
products.sort()
products
# Out:
# array(['ROIC Annual', 'ROIC Monthly'], dtype=object)

# %%
# dropping ROIC annual from dataset
data = data[data["product_name"].str.contains("ROIC Annual") == False]
data
# Out:
#        trans_id created_date expires_date  user_id  product_name  \
# 0             3   2020-05-08     6/8/2020      4.0  ROIC Monthly
# 1             7   2020-05-09     6/9/2020      6.0  ROIC Monthly
# 2             9   2020-05-09     6/9/2020      7.0  ROIC Monthly
# 3            12   2020-05-09     6/9/2020      9.0  ROIC Monthly
# 4            15   2020-05-09     6/9/2020     11.0  ROIC Monthly
# ...         ...          ...          ...      ...           ...
# 64550     73466   2022-07-25    8/25/2022   4187.0  ROIC Monthly
# 64551     73467   2022-07-26    8/25/2022   6432.0  ROIC Monthly
# 64552     73468   2022-07-26    8/25/2022   2521.0  ROIC Monthly
# 64553     73469   2022-07-26    8/25/2022   5506.0  ROIC Monthly
# 64554     73470   2022-07-26    8/25/2022   6433.0  ROIC Monthly
#
#                    payment_method  sub_id  amount    status  coupon_id  \
# 0      Debit/Credit Card (Stripe)       2    6.99  complete          0
# 1      Debit/Credit Card (Stripe)       5    7.49  complete          0
# 2      Debit/Credit Card (Stripe)       6    7.49  complete          0
# 3      Debit/Credit Card (Stripe)       8    7.49  complete          0
# 4      Debit/Credit Card (Stripe)      10    7.49   pending       2356
# ...                           ...     ...     ...       ...        ...
# 64550  Debit/Credit Card (Stripe)    4789    9.99  complete          0
# 64551  Debit/Credit Card (Stripe)    7596   11.99  complete          0
# 64552  Debit/Credit Card (Stripe)    2828    9.99  complete          0
# 64553  Debit/Credit Card (Stripe)    6356   10.99  complete       6602
# 64554  Debit/Credit Card (Stripe)    7597   11.99  complete          0
#
#       user_ctry  user_logins  on_discord hear_about  tenure  ltv_amount
# 0            US           50           0    Unknown       8       59.42
# 1            US           49           0    Unknown      27      202.23
# 2            US           14           0    Unknown       1        7.49
# 3            GB            3           0    Unknown       8       59.92
# 4            US            1           0    Unknown       1        0.00
# ...         ...          ...         ...        ...     ...         ...
# 64550        US          482           1    YouTube      18      179.82
# 64551        CA          135           1    YouTube      12      143.88
# 64552        US          179           1    Unknown      20      199.80
# 64553        US           39           1    YouTube      15      164.85
# 64554        CA           40           1    YouTube      12      143.88
#
# [62486 rows x 16 columns]

# %%
# create a transaction month
import datetime as dt

#function for month
def get_month(x):
    return dt.datetime(x.year, x.month,1)

#apply the function
data['trans_month'] = data['created_date'].apply(get_month)
data.tail()
# Out:
#        trans_id created_date expires_date  user_id  product_name  \
# 64550     73466   2022-07-25    8/25/2022   4187.0  ROIC Monthly
# 64551     73467   2022-07-26    8/25/2022   6432.0  ROIC Monthly
# 64552     73468   2022-07-26    8/25/2022   2521.0  ROIC Monthly
# 64553     73469   2022-07-26    8/25/2022   5506.0  ROIC Monthly
# 64554     73470   2022-07-26    8/25/2022   6433.0  ROIC Monthly
#
#                    payment_method  sub_id  amount    status  coupon_id  \
# 64550  Debit/Credit Card (Stripe)    4789    9.99  complete          0
# 64551  Debit/Credit Card (Stripe)    7596   11.99  complete          0
# 64552  Debit/Credit Card (Stripe)    2828    9.99  complete          0
# 64553  Debit/Credit Card (Stripe)    6356   10.99  complete       6602
# 64554  Debit/Credit Card (Stripe)    7597   11.99  complete          0
#
#       user_ctry  user_logins  on_discord hear_about  tenure  ltv_amount  \
# 64550        US          482           1    YouTube      18      179.82
# 64551        CA          135           1    YouTube      12      143.88
# 64552        US          179           1    Unknown      20      199.80
# 64553        US           39           1    YouTube      15      164.85
# 64554        CA           40           1    YouTube      12      143.88
#
#       trans_month
# 64550  2022-07-01
# 64551  2022-07-01
# 64552  2022-07-01
# 64553  2022-07-01
# 64554  2022-07-01

# %%
# create a column index with the minimum invoice date aka first time customer was acquired
data['cohort_month'] = data.groupby('user_id')['trans_month'].transform('min')
data.head(30)
# Out:
#     trans_id created_date expires_date  user_id  product_name  \
# 0          3   2020-05-08     6/8/2020      4.0  ROIC Monthly
# 1          7   2020-05-09     6/9/2020      6.0  ROIC Monthly
# 2          9   2020-05-09     6/9/2020      7.0  ROIC Monthly
# 3         12   2020-05-09     6/9/2020      9.0  ROIC Monthly
# 4         15   2020-05-09     6/9/2020     11.0  ROIC Monthly
# 5         17   2020-05-09     6/9/2020     12.0  ROIC Monthly
# 6         19   2020-05-09     6/9/2020     13.0  ROIC Monthly
# 7         21   2020-05-09     6/9/2020     14.0  ROIC Monthly
# 8         24   2020-05-09     5/8/2020     16.0  ROIC Monthly
# 9         25   2020-05-09     6/9/2020     16.0  ROIC Monthly
# 10        27   2020-05-09     6/9/2020     17.0  ROIC Monthly
# 11        33   2020-05-10    6/10/2020     22.0  ROIC Monthly
# 12        38   2020-05-10    6/10/2020     26.0  ROIC Monthly
# 13        40   2020-05-10    6/10/2020     27.0  ROIC Monthly
# 14        43   2020-05-10    6/10/2020     29.0  ROIC Monthly
# 15        48   2020-05-10    6/10/2020     32.0  ROIC Monthly
# 16        49   2020-05-10    6/10/2020     33.0  ROIC Monthly
# 17        51   2020-05-10    6/10/2020     34.0  ROIC Monthly
# 18        54   2020-05-10    6/10/2020     36.0  ROIC Monthly
# 19        57   2020-05-10    6/10/2020     38.0  ROIC Monthly
# 20        60   2020-05-11    6/11/2020     40.0  ROIC Monthly
# 21        62   2020-05-11    6/11/2020     41.0  ROIC Monthly
# 23        70   2020-05-11    6/10/2020     47.0  ROIC Monthly
# 24        72   2020-05-11    6/11/2020     48.0  ROIC Monthly
# 25        75   2020-05-11    6/11/2020     50.0  ROIC Monthly
# 26        77   2020-05-11    6/11/2020     51.0  ROIC Monthly
# 27        80   2020-05-11    6/11/2020     53.0  ROIC Monthly
# 28        82   2020-05-11    6/11/2020     54.0  ROIC Monthly
# 29        84   2020-05-11    6/11/2020     55.0  ROIC Monthly
# 30        87   2020-05-11    6/11/2020     57.0  ROIC Monthly
#
#                 payment_method  sub_id  amount    status  coupon_id user_ctry  \
# 0   Debit/Credit Card (Stripe)       2    6.99  complete          0        US
# 1   Debit/Credit Card (Stripe)       5    7.49  complete          0        US
# 2   Debit/Credit Card (Stripe)       6    7.49  complete          0        US
# 3   Debit/Credit Card (Stripe)       8    7.49  complete          0        GB
# 4   Debit/Credit Card (Stripe)      10    7.49   pending       2356        US
# 5   Debit/Credit Card (Stripe)      11    7.49  complete          0        US
# 6   Debit/Credit Card (Stripe)      12    7.49  complete          0        US
# 7   Debit/Credit Card (Stripe)      13    7.49  complete          0        US
# 8   Debit/Credit Card (Stripe)      15    7.49    failed          0        IE
# 9   Debit/Credit Card (Stripe)      15    7.49  complete          0        IE
# 10  Debit/Credit Card (Stripe)      16    7.49  complete          0        US
# 11  Debit/Credit Card (Stripe)      21    7.49  complete          0        US
# 12  Debit/Credit Card (Stripe)      25    7.49  complete          0        US
# 13  Debit/Credit Card (Stripe)      26    7.49  complete          0        AU
# 14  Debit/Credit Card (Stripe)      28    7.49  complete          0        PE
# 15  Debit/Credit Card (Stripe)      31    7.49  complete          0        US
# 16  Debit/Credit Card (Stripe)      32    7.49  refunded          0        US
# 17  Debit/Credit Card (Stripe)      33    7.49  complete          0        US
# 18  Debit/Credit Card (Stripe)      35    7.49  complete          0        US
# 19  Debit/Credit Card (Stripe)      37    7.49  complete          0        US
# 20  Debit/Credit Card (Stripe)      39    7.49  complete          0        US
# 21  Debit/Credit Card (Stripe)      40    7.49  complete          0        US
# 23  Debit/Credit Card (Stripe)      46    7.49  complete          0        AT
# 24  Debit/Credit Card (Stripe)      47    7.49  complete          0        US
# 25  Debit/Credit Card (Stripe)      49    7.49  complete          0        US
# 26  Debit/Credit Card (Stripe)      50    7.49  complete          0        US
# 27  Debit/Credit Card (Stripe)      52    7.49  complete          0        US
# 28  Debit/Credit Card (Stripe)      53    7.49  complete          0        US
# 29  Debit/Credit Card (Stripe)      54    7.49  complete          0        US
# 30  Debit/Credit Card (Stripe)      56    7.49  complete          0        CA
#
#     user_logins  on_discord     hear_about  tenure  ltv_amount trans_month  \
# 0            50           0        Unknown       8       59.42  2020-05-01
# 1            49           0        Unknown      27      202.23  2020-05-01
# 2            14           0        Unknown       1        7.49  2020-05-01
# 3             3           0        Unknown       8       59.92  2020-05-01
# 4             1           0        Unknown       1        0.00  2020-05-01
# 5            67           0        Unknown      27      202.23  2020-05-01
# 6            42           0      Instagram      24      217.36  2020-05-01
# 7            16           0        Unknown      17      127.33  2020-05-01
# 8           175           0  Word of Mouth      22      159.91  2020-05-01
# 9           175           0  Word of Mouth      22      159.91  2020-05-01
# 10          308           1        YouTube      22      267.39  2020-05-01
# 11           16           0        Unknown       1        7.49  2020-05-01
# 12           14           0        Unknown       4       29.96  2020-05-01
# 13            2           0        Unknown       2       14.98  2020-05-01
# 14            7           0        Unknown      14       97.37  2020-05-01
# 15           23           0        Unknown      27      202.23  2020-05-01
# 16           11           0        Unknown       1        0.00  2020-05-01
# 17           39           0        Unknown      16      119.84  2020-05-01
# 18          205           1        Unknown      27      202.23  2020-05-01
# 19          112           0        Unknown      27      202.23  2020-05-01
# 20           54           0        YouTube      19      122.38  2020-05-01
# 21           38           0        Unknown      11       74.91  2020-05-01
# 23           19           0        Unknown       3       22.47  2020-05-01
# 24           10           0        Unknown       1        7.49  2020-05-01
# 25           15           0         TikTok       9       17.48  2020-05-01
# 26           35           0        Unknown      27      202.23  2020-05-01
# 27           31           0        Unknown      27      202.23  2020-05-01
# 28          421           1        Unknown      27      202.23  2020-05-01
# 29           49           0        Unknown      21      149.80  2020-05-01
# 30            5           0        Unknown      27      202.23  2020-05-01
#
#    cohort_month
# 0    2020-05-01
# 1    2020-05-01
# 2    2020-05-01
# 3    2020-05-01
# 4    2020-05-01
# 5    2020-05-01
# 6    2020-05-01
# 7    2020-05-01
# 8    2020-05-01
# 9    2020-05-01
# 10   2020-05-01
# 11   2020-05-01
# 12   2020-05-01
# 13   2020-05-01
# 14   2020-05-01
# 15   2020-05-01
# 16   2020-05-01
# 17   2020-05-01
# 18   2020-05-01
# 19   2020-05-01
# 20   2020-05-01
# 21   2020-05-01
# 23   2020-05-01
# 24   2020-05-01
# 25   2020-05-01
# 26   2020-05-01
# 27   2020-05-01
# 28   2020-05-01
# 29   2020-05-01
# 30   2020-05-01

# %%
data.tail()
# Out:
#        trans_id created_date expires_date  user_id  product_name  \
# 64550     73466   2022-07-25    8/25/2022   4187.0  ROIC Monthly
# 64551     73467   2022-07-26    8/25/2022   6432.0  ROIC Monthly
# 64552     73468   2022-07-26    8/25/2022   2521.0  ROIC Monthly
# 64553     73469   2022-07-26    8/25/2022   5506.0  ROIC Monthly
# 64554     73470   2022-07-26    8/25/2022   6433.0  ROIC Monthly
#
#                    payment_method  sub_id  amount    status  coupon_id  \
# 64550  Debit/Credit Card (Stripe)    4789    9.99  complete          0
# 64551  Debit/Credit Card (Stripe)    7596   11.99  complete          0
# 64552  Debit/Credit Card (Stripe)    2828    9.99  complete          0
# 64553  Debit/Credit Card (Stripe)    6356   10.99  complete       6602
# 64554  Debit/Credit Card (Stripe)    7597   11.99  complete          0
#
#       user_ctry  user_logins  on_discord hear_about  tenure  ltv_amount  \
# 64550        US          482           1    YouTube      18      179.82
# 64551        CA          135           1    YouTube      12      143.88
# 64552        US          179           1    Unknown      20      199.80
# 64553        US           39           1    YouTube      15      164.85
# 64554        CA           40           1    YouTube      12      143.88
#
#       trans_month cohort_month
# 64550  2022-07-01   2021-02-01
# 64551  2022-07-01   2021-08-01
# 64552  2022-07-01   2020-12-01
# 64553  2022-07-01   2021-05-01
# 64554  2022-07-01   2021-08-01

# %%
# create a data element function to get a series for subtraction
def get_date_elements(df, column):
    day = df[column].dt.day
    month = df[column].dt.month
    year = df[column].dt.year
    return day, month, year

# %%
# get date elements for our cohort and invoice columns
trans_day,trans_month,trans_year = get_date_elements(data, 'trans_month')
cohort_day,cohort_month,cohort_year = get_date_elements(data, 'cohort_month')

# %%
# check the series
cohort_month[:10]
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# 6    5
# 7    5
# 8    5
# 9    5
# Name: cohort_month, dtype: int64

# %%
# create a cohort index
# this will show us when a user was acquired
year_diff = trans_year - cohort_year
month_diff = trans_month - cohort_month

# multiply a year difference by 12
# add a 1 to avoid 0 month subs
data['cohort_index'] = year_diff*12+month_diff+1
data.head(30)
# Out:
#     trans_id created_date expires_date  user_id  product_name  \
# 0          3   2020-05-08     6/8/2020      4.0  ROIC Monthly
# 1          7   2020-05-09     6/9/2020      6.0  ROIC Monthly
# 2          9   2020-05-09     6/9/2020      7.0  ROIC Monthly
# 3         12   2020-05-09     6/9/2020      9.0  ROIC Monthly
# 4         15   2020-05-09     6/9/2020     11.0  ROIC Monthly
# 5         17   2020-05-09     6/9/2020     12.0  ROIC Monthly
# 6         19   2020-05-09     6/9/2020     13.0  ROIC Monthly
# 7         21   2020-05-09     6/9/2020     14.0  ROIC Monthly
# 8         24   2020-05-09     5/8/2020     16.0  ROIC Monthly
# 9         25   2020-05-09     6/9/2020     16.0  ROIC Monthly
# 10        27   2020-05-09     6/9/2020     17.0  ROIC Monthly
# 11        33   2020-05-10    6/10/2020     22.0  ROIC Monthly
# 12        38   2020-05-10    6/10/2020     26.0  ROIC Monthly
# 13        40   2020-05-10    6/10/2020     27.0  ROIC Monthly
# 14        43   2020-05-10    6/10/2020     29.0  ROIC Monthly
# 15        48   2020-05-10    6/10/2020     32.0  ROIC Monthly
# 16        49   2020-05-10    6/10/2020     33.0  ROIC Monthly
# 17        51   2020-05-10    6/10/2020     34.0  ROIC Monthly
# 18        54   2020-05-10    6/10/2020     36.0  ROIC Monthly
# 19        57   2020-05-10    6/10/2020     38.0  ROIC Monthly
# 20        60   2020-05-11    6/11/2020     40.0  ROIC Monthly
# 21        62   2020-05-11    6/11/2020     41.0  ROIC Monthly
# 23        70   2020-05-11    6/10/2020     47.0  ROIC Monthly
# 24        72   2020-05-11    6/11/2020     48.0  ROIC Monthly
# 25        75   2020-05-11    6/11/2020     50.0  ROIC Monthly
# 26        77   2020-05-11    6/11/2020     51.0  ROIC Monthly
# 27        80   2020-05-11    6/11/2020     53.0  ROIC Monthly
# 28        82   2020-05-11    6/11/2020     54.0  ROIC Monthly
# 29        84   2020-05-11    6/11/2020     55.0  ROIC Monthly
# 30        87   2020-05-11    6/11/2020     57.0  ROIC Monthly
#
#                 payment_method  sub_id  amount    status  coupon_id user_ctry  \
# 0   Debit/Credit Card (Stripe)       2    6.99  complete          0        US
# 1   Debit/Credit Card (Stripe)       5    7.49  complete          0        US
# 2   Debit/Credit Card (Stripe)       6    7.49  complete          0        US
# 3   Debit/Credit Card (Stripe)       8    7.49  complete          0        GB
# 4   Debit/Credit Card (Stripe)      10    7.49   pending       2356        US
# 5   Debit/Credit Card (Stripe)      11    7.49  complete          0        US
# 6   Debit/Credit Card (Stripe)      12    7.49  complete          0        US
# 7   Debit/Credit Card (Stripe)      13    7.49  complete          0        US
# 8   Debit/Credit Card (Stripe)      15    7.49    failed          0        IE
# 9   Debit/Credit Card (Stripe)      15    7.49  complete          0        IE
# 10  Debit/Credit Card (Stripe)      16    7.49  complete          0        US
# 11  Debit/Credit Card (Stripe)      21    7.49  complete          0        US
# 12  Debit/Credit Card (Stripe)      25    7.49  complete          0        US
# 13  Debit/Credit Card (Stripe)      26    7.49  complete          0        AU
# 14  Debit/Credit Card (Stripe)      28    7.49  complete          0        PE
# 15  Debit/Credit Card (Stripe)      31    7.49  complete          0        US
# 16  Debit/Credit Card (Stripe)      32    7.49  refunded          0        US
# 17  Debit/Credit Card (Stripe)      33    7.49  complete          0        US
# 18  Debit/Credit Card (Stripe)      35    7.49  complete          0        US
# 19  Debit/Credit Card (Stripe)      37    7.49  complete          0        US
# 20  Debit/Credit Card (Stripe)      39    7.49  complete          0        US
# 21  Debit/Credit Card (Stripe)      40    7.49  complete          0        US
# 23  Debit/Credit Card (Stripe)      46    7.49  complete          0        AT
# 24  Debit/Credit Card (Stripe)      47    7.49  complete          0        US
# 25  Debit/Credit Card (Stripe)      49    7.49  complete          0        US
# 26  Debit/Credit Card (Stripe)      50    7.49  complete          0        US
# 27  Debit/Credit Card (Stripe)      52    7.49  complete          0        US
# 28  Debit/Credit Card (Stripe)      53    7.49  complete          0        US
# 29  Debit/Credit Card (Stripe)      54    7.49  complete          0        US
# 30  Debit/Credit Card (Stripe)      56    7.49  complete          0        CA
#
#     user_logins  on_discord     hear_about  tenure  ltv_amount trans_month  \
# 0            50           0        Unknown       8       59.42  2020-05-01
# 1            49           0        Unknown      27      202.23  2020-05-01
# 2            14           0        Unknown       1        7.49  2020-05-01
# 3             3           0        Unknown       8       59.92  2020-05-01
# 4             1           0        Unknown       1        0.00  2020-05-01
# 5            67           0        Unknown      27      202.23  2020-05-01
# 6            42           0      Instagram      24      217.36  2020-05-01
# 7            16           0        Unknown      17      127.33  2020-05-01
# 8           175           0  Word of Mouth      22      159.91  2020-05-01
# 9           175           0  Word of Mouth      22      159.91  2020-05-01
# 10          308           1        YouTube      22      267.39  2020-05-01
# 11           16           0        Unknown       1        7.49  2020-05-01
# 12           14           0        Unknown       4       29.96  2020-05-01
# 13            2           0        Unknown       2       14.98  2020-05-01
# 14            7           0        Unknown      14       97.37  2020-05-01
# 15           23           0        Unknown      27      202.23  2020-05-01
# 16           11           0        Unknown       1        0.00  2020-05-01
# 17           39           0        Unknown      16      119.84  2020-05-01
# 18          205           1        Unknown      27      202.23  2020-05-01
# 19          112           0        Unknown      27      202.23  2020-05-01
# 20           54           0        YouTube      19      122.38  2020-05-01
# 21           38           0        Unknown      11       74.91  2020-05-01
# 23           19           0        Unknown       3       22.47  2020-05-01
# 24           10           0        Unknown       1        7.49  2020-05-01
# 25           15           0         TikTok       9       17.48  2020-05-01
# 26           35           0        Unknown      27      202.23  2020-05-01
# 27           31           0        Unknown      27      202.23  2020-05-01
# 28          421           1        Unknown      27      202.23  2020-05-01
# 29           49           0        Unknown      21      149.80  2020-05-01
# 30            5           0        Unknown      27      202.23  2020-05-01
#
#    cohort_month  cohort_index
# 0    2020-05-01             1
# 1    2020-05-01             1
# 2    2020-05-01             1
# 3    2020-05-01             1
# 4    2020-05-01             1
# 5    2020-05-01             1
# 6    2020-05-01             1
# 7    2020-05-01             1
# 8    2020-05-01             1
# 9    2020-05-01             1
# 10   2020-05-01             1
# 11   2020-05-01             1
# 12   2020-05-01             1
# 13   2020-05-01             1
# 14   2020-05-01             1
# 15   2020-05-01             1
# 16   2020-05-01             1
# 17   2020-05-01             1
# 18   2020-05-01             1
# 19   2020-05-01             1
# 20   2020-05-01             1
# 21   2020-05-01             1
# 23   2020-05-01             1
# 24   2020-05-01             1
# 25   2020-05-01             1
# 26   2020-05-01             1
# 27   2020-05-01             1
# 28   2020-05-01             1
# 29   2020-05-01             1
# 30   2020-05-01             1

# %%
data.tail()
# Out:
#        trans_id created_date expires_date  user_id  product_name  \
# 64550     73466   2022-07-25    8/25/2022   4187.0  ROIC Monthly
# 64551     73467   2022-07-26    8/25/2022   6432.0  ROIC Monthly
# 64552     73468   2022-07-26    8/25/2022   2521.0  ROIC Monthly
# 64553     73469   2022-07-26    8/25/2022   5506.0  ROIC Monthly
# 64554     73470   2022-07-26    8/25/2022   6433.0  ROIC Monthly
#
#                    payment_method  sub_id  amount    status  coupon_id  \
# 64550  Debit/Credit Card (Stripe)    4789    9.99  complete          0
# 64551  Debit/Credit Card (Stripe)    7596   11.99  complete          0
# 64552  Debit/Credit Card (Stripe)    2828    9.99  complete          0
# 64553  Debit/Credit Card (Stripe)    6356   10.99  complete       6602
# 64554  Debit/Credit Card (Stripe)    7597   11.99  complete          0
#
#       user_ctry  user_logins  on_discord hear_about  tenure  ltv_amount  \
# 64550        US          482           1    YouTube      18      179.82
# 64551        CA          135           1    YouTube      12      143.88
# 64552        US          179           1    Unknown      20      199.80
# 64553        US           39           1    YouTube      15      164.85
# 64554        CA           40           1    YouTube      12      143.88
#
#       trans_month cohort_month  cohort_index
# 64550  2022-07-01   2021-02-01            18
# 64551  2022-07-01   2021-08-01            12
# 64552  2022-07-01   2020-12-01            20
# 64553  2022-07-01   2021-05-01            15
# 64554  2022-07-01   2021-08-01            12

# %%
# count the user_id by grouping by cohort month and cohort index
cohort_data = data.groupby(['cohort_month','cohort_index'])['user_id'].apply(pd.Series.nunique).reset_index()
cohort_data
# Out:
#     cohort_month  cohort_index  user_id
# 0     2020-05-01             1      351
# 1     2020-05-01             2      294
# 2     2020-05-01             3      274
# 3     2020-05-01             4      246
# 4     2020-05-01             5      223
# ..           ...           ...      ...
# 373   2022-05-01             2        9
# 374   2022-05-01             3        7
# 375   2022-06-01             1        8
# 376   2022-06-01             2        5
# 377   2022-07-01             1        4
#
# [378 rows x 3 columns]

# %%
# create a pivot table
cohort_table = cohort_data.pivot(index='cohort_month', columns=['cohort_index'], values='user_id')
cohort_table
# Out:
# cohort_index     1      2      3      4      5      6      7      8      9   \
# cohort_month
# 2020-05-01    351.0  294.0  274.0  246.0  223.0  204.0  200.0  194.0  189.0
# 2020-06-01    405.0  328.0  289.0  258.0  229.0  224.0  214.0  213.0  212.0
# 2020-07-01    164.0  141.0  123.0  114.0  111.0  115.0  113.0  112.0  110.0
# 2020-08-01    100.0   78.0   73.0   69.0   66.0   64.0   64.0   62.0   63.0
# 2020-09-01    144.0  119.0  112.0  110.0  105.0  100.0   99.0   94.0   92.0
# 2020-10-01    158.0  140.0  137.0  131.0  126.0  124.0  118.0  117.0  117.0
# 2020-11-01    308.0  280.0  257.0  238.0  242.0  233.0  230.0  222.0  220.0
# 2020-12-01    672.0  559.0  502.0  459.0  428.0  408.0  387.0  368.0  358.0
# 2021-01-01    378.0  310.0  293.0  271.0  264.0  243.0  235.0  225.0  215.0
# 2021-02-01    872.0  755.0  677.0  623.0  583.0  562.0  547.0  526.0  509.0
# 2021-03-01    605.0  526.0  484.0  442.0  429.0  411.0  397.0  385.0  363.0
# 2021-04-01    283.0  239.0  214.0  195.0  187.0  183.0  171.0  157.0  151.0
# 2021-05-01    212.0  186.0  166.0  160.0  151.0  140.0  124.0  120.0  111.0
# 2021-06-01     95.0   80.0   72.0   70.0   67.0   65.0   59.0   56.0   51.0
# 2021-07-01    122.0  102.0   90.0   85.0   74.0   73.0   67.0   62.0   57.0
# 2021-08-01    165.0  126.0  111.0   94.0   91.0   83.0   81.0   73.0   66.0
# 2021-09-01     75.0   62.0   53.0   49.0   44.0   40.0   40.0   35.0   33.0
# 2021-10-01     94.0   74.0   62.0   54.0   50.0   49.0   45.0   43.0   39.0
# 2021-11-01     85.0   64.0   50.0   41.0   37.0   32.0   30.0   24.0   20.0
# 2021-12-01     44.0   29.0   26.0   21.0   21.0   19.0   17.0   10.0    NaN
# 2022-01-01     51.0   35.0   28.0   24.0   22.0   20.0   10.0    NaN    NaN
# 2022-02-01     27.0   21.0   14.0   15.0   12.0   10.0    NaN    NaN    NaN
# 2022-03-01     32.0   21.0   18.0   15.0   12.0    NaN    NaN    NaN    NaN
# 2022-04-01     17.0   13.0   12.0   11.0    NaN    NaN    NaN    NaN    NaN
# 2022-05-01     14.0    9.0    7.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-06-01      8.0    5.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-07-01      4.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# cohort_index     10  ...     18     19     20     21     22     23     24  \
# cohort_month         ...
# 2020-05-01    185.0  ...  146.0  141.0  138.0  130.0  118.0  114.0  109.0
# 2020-06-01    205.0  ...  165.0  166.0  164.0  148.0  142.0  139.0  133.0
# 2020-07-01    105.0  ...   90.0   87.0   85.0   79.0   74.0   71.0   69.0
# 2020-08-01     56.0  ...   47.0   44.0   41.0   40.0   39.0   38.0   28.0
# 2020-09-01     89.0  ...   73.0   69.0   67.0   66.0   63.0   58.0    NaN
# 2020-10-01    113.0  ...   99.0   95.0   94.0   90.0   43.0    NaN    NaN
# 2020-11-01    220.0  ...  161.0  151.0  145.0  118.0    NaN    NaN    NaN
# 2020-12-01    345.0  ...  227.0  213.0  170.0    NaN    NaN    NaN    NaN
# 2021-01-01    209.0  ...  146.0  103.0    NaN    NaN    NaN    NaN    NaN
# 2021-02-01    481.0  ...  275.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-03-01    341.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-04-01    149.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-05-01    106.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-06-01     48.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-07-01     51.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-08-01     60.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-09-01     27.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-10-01     30.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-11-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2021-12-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-01-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-02-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-03-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-04-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-05-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-06-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2022-07-01      NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# cohort_index     25     26    27
# cohort_month
# 2020-05-01    105.0   98.0  76.0
# 2020-06-01    127.0  106.0   NaN
# 2020-07-01     52.0    NaN   NaN
# 2020-08-01      NaN    NaN   NaN
# 2020-09-01      NaN    NaN   NaN
# 2020-10-01      NaN    NaN   NaN
# 2020-11-01      NaN    NaN   NaN
# 2020-12-01      NaN    NaN   NaN
# 2021-01-01      NaN    NaN   NaN
# 2021-02-01      NaN    NaN   NaN
# 2021-03-01      NaN    NaN   NaN
# 2021-04-01      NaN    NaN   NaN
# 2021-05-01      NaN    NaN   NaN
# 2021-06-01      NaN    NaN   NaN
# 2021-07-01      NaN    NaN   NaN
# 2021-08-01      NaN    NaN   NaN
# 2021-09-01      NaN    NaN   NaN
# 2021-10-01      NaN    NaN   NaN
# 2021-11-01      NaN    NaN   NaN
# 2021-12-01      NaN    NaN   NaN
# 2022-01-01      NaN    NaN   NaN
# 2022-02-01      NaN    NaN   NaN
# 2022-03-01      NaN    NaN   NaN
# 2022-04-01      NaN    NaN   NaN
# 2022-05-01      NaN    NaN   NaN
# 2022-06-01      NaN    NaN   NaN
# 2022-07-01      NaN    NaN   NaN
#
# [27 rows x 27 columns]

# %%
# change axis titles to Month Year
cohort_table.index = cohort_table.index.strftime('%B %Y')

# %%
# change index

# visualize results in heatmap
plt.figure(figsize=(50,30))
sns.heatmap(cohort_table, annot=True,cmap='Blues')
# Out:
# <AxesSubplot:xlabel='cohort_index', ylabel='cohort_month'>

# %%
# cohort table for percentage
new_cohort_table = cohort_table.divide(cohort_table.iloc[:,0],axis=0)
new_cohort_table
# Out:
# cohort_index     1         2         3         4         5         6   \
# cohort_month
# May 2020        1.0  0.837607  0.780627  0.700855  0.635328  0.581197
# June 2020       1.0  0.809877  0.713580  0.637037  0.565432  0.553086
# July 2020       1.0  0.859756  0.750000  0.695122  0.676829  0.701220
# August 2020     1.0  0.780000  0.730000  0.690000  0.660000  0.640000
# September 2020  1.0  0.826389  0.777778  0.763889  0.729167  0.694444
# October 2020    1.0  0.886076  0.867089  0.829114  0.797468  0.784810
# November 2020   1.0  0.909091  0.834416  0.772727  0.785714  0.756494
# December 2020   1.0  0.831845  0.747024  0.683036  0.636905  0.607143
# January 2021    1.0  0.820106  0.775132  0.716931  0.698413  0.642857
# February 2021   1.0  0.865826  0.776376  0.714450  0.668578  0.644495
# March 2021      1.0  0.869421  0.800000  0.730579  0.709091  0.679339
# April 2021      1.0  0.844523  0.756184  0.689046  0.660777  0.646643
# May 2021        1.0  0.877358  0.783019  0.754717  0.712264  0.660377
# June 2021       1.0  0.842105  0.757895  0.736842  0.705263  0.684211
# July 2021       1.0  0.836066  0.737705  0.696721  0.606557  0.598361
# August 2021     1.0  0.763636  0.672727  0.569697  0.551515  0.503030
# September 2021  1.0  0.826667  0.706667  0.653333  0.586667  0.533333
# October 2021    1.0  0.787234  0.659574  0.574468  0.531915  0.521277
# November 2021   1.0  0.752941  0.588235  0.482353  0.435294  0.376471
# December 2021   1.0  0.659091  0.590909  0.477273  0.477273  0.431818
# January 2022    1.0  0.686275  0.549020  0.470588  0.431373  0.392157
# February 2022   1.0  0.777778  0.518519  0.555556  0.444444  0.370370
# March 2022      1.0  0.656250  0.562500  0.468750  0.375000       NaN
# April 2022      1.0  0.764706  0.705882  0.647059       NaN       NaN
# May 2022        1.0  0.642857  0.500000       NaN       NaN       NaN
# June 2022       1.0  0.625000       NaN       NaN       NaN       NaN
# July 2022       1.0       NaN       NaN       NaN       NaN       NaN
#
# cohort_index          7         8         9         10  ...        18  \
# cohort_month                                            ...
# May 2020        0.569801  0.552707  0.538462  0.527066  ...  0.415954
# June 2020       0.528395  0.525926  0.523457  0.506173  ...  0.407407
# July 2020       0.689024  0.682927  0.670732  0.640244  ...  0.548780
# August 2020     0.640000  0.620000  0.630000  0.560000  ...  0.470000
# September 2020  0.687500  0.652778  0.638889  0.618056  ...  0.506944
# October 2020    0.746835  0.740506  0.740506  0.715190  ...  0.626582
# November 2020   0.746753  0.720779  0.714286  0.714286  ...  0.522727
# December 2020   0.575893  0.547619  0.532738  0.513393  ...  0.337798
# January 2021    0.621693  0.595238  0.568783  0.552910  ...  0.386243
# February 2021   0.627294  0.603211  0.583716  0.551606  ...  0.315367
# March 2021      0.656198  0.636364  0.600000  0.563636  ...       NaN
# April 2021      0.604240  0.554770  0.533569  0.526502  ...       NaN
# May 2021        0.584906  0.566038  0.523585  0.500000  ...       NaN
# June 2021       0.621053  0.589474  0.536842  0.505263  ...       NaN
# July 2021       0.549180  0.508197  0.467213  0.418033  ...       NaN
# August 2021     0.490909  0.442424  0.400000  0.363636  ...       NaN
# September 2021  0.533333  0.466667  0.440000  0.360000  ...       NaN
# October 2021    0.478723  0.457447  0.414894  0.319149  ...       NaN
# November 2021   0.352941  0.282353  0.235294       NaN  ...       NaN
# December 2021   0.386364  0.227273       NaN       NaN  ...       NaN
# January 2022    0.196078       NaN       NaN       NaN  ...       NaN
# February 2022        NaN       NaN       NaN       NaN  ...       NaN
# March 2022           NaN       NaN       NaN       NaN  ...       NaN
# April 2022           NaN       NaN       NaN       NaN  ...       NaN
# May 2022             NaN       NaN       NaN       NaN  ...       NaN
# June 2022            NaN       NaN       NaN       NaN  ...       NaN
# July 2022            NaN       NaN       NaN       NaN  ...       NaN
#
# cohort_index          19        20        21        22        23        24  \
# cohort_month
# May 2020        0.401709  0.393162  0.370370  0.336182  0.324786  0.310541
# June 2020       0.409877  0.404938  0.365432  0.350617  0.343210  0.328395
# July 2020       0.530488  0.518293  0.481707  0.451220  0.432927  0.420732
# August 2020     0.440000  0.410000  0.400000  0.390000  0.380000  0.280000
# September 2020  0.479167  0.465278  0.458333  0.437500  0.402778       NaN
# October 2020    0.601266  0.594937  0.569620  0.272152       NaN       NaN
# November 2020   0.490260  0.470779  0.383117       NaN       NaN       NaN
# December 2020   0.316964  0.252976       NaN       NaN       NaN       NaN
# January 2021    0.272487       NaN       NaN       NaN       NaN       NaN
# February 2021        NaN       NaN       NaN       NaN       NaN       NaN
# March 2021           NaN       NaN       NaN       NaN       NaN       NaN
# April 2021           NaN       NaN       NaN       NaN       NaN       NaN
# May 2021             NaN       NaN       NaN       NaN       NaN       NaN
# June 2021            NaN       NaN       NaN       NaN       NaN       NaN
# July 2021            NaN       NaN       NaN       NaN       NaN       NaN
# August 2021          NaN       NaN       NaN       NaN       NaN       NaN
# September 2021       NaN       NaN       NaN       NaN       NaN       NaN
# October 2021         NaN       NaN       NaN       NaN       NaN       NaN
# November 2021        NaN       NaN       NaN       NaN       NaN       NaN
# December 2021        NaN       NaN       NaN       NaN       NaN       NaN
# January 2022         NaN       NaN       NaN       NaN       NaN       NaN
# February 2022        NaN       NaN       NaN       NaN       NaN       NaN
# March 2022           NaN       NaN       NaN       NaN       NaN       NaN
# April 2022           NaN       NaN       NaN       NaN       NaN       NaN
# May 2022             NaN       NaN       NaN       NaN       NaN       NaN
# June 2022            NaN       NaN       NaN       NaN       NaN       NaN
# July 2022            NaN       NaN       NaN       NaN       NaN       NaN
#
# cohort_index          25        26        27
# cohort_month
# May 2020        0.299145  0.279202  0.216524
# June 2020       0.313580  0.261728       NaN
# July 2020       0.317073       NaN       NaN
# August 2020          NaN       NaN       NaN
# September 2020       NaN       NaN       NaN
# October 2020         NaN       NaN       NaN
# November 2020        NaN       NaN       NaN
# December 2020        NaN       NaN       NaN
# January 2021         NaN       NaN       NaN
# February 2021        NaN       NaN       NaN
# March 2021           NaN       NaN       NaN
# April 2021           NaN       NaN       NaN
# May 2021             NaN       NaN       NaN
# June 2021            NaN       NaN       NaN
# July 2021            NaN       NaN       NaN
# August 2021          NaN       NaN       NaN
# September 2021       NaN       NaN       NaN
# October 2021         NaN       NaN       NaN
# November 2021        NaN       NaN       NaN
# December 2021        NaN       NaN       NaN
# January 2022         NaN       NaN       NaN
# February 2022        NaN       NaN       NaN
# March 2022           NaN       NaN       NaN
# April 2022           NaN       NaN       NaN
# May 2022             NaN       NaN       NaN
# June 2022            NaN       NaN       NaN
# July 2022            NaN       NaN       NaN
#
# [27 rows x 27 columns]

# %%
#create percentage visual
plt.figure(figsize=(22,11))
sns.heatmap(new_cohort_table, annot=True,cmap='magma',fmt='.0%')
# Out:
# <AxesSubplot:xlabel='cohort_index', ylabel='cohort_month'>
